# %% [markdown]
# In what follows we will attempt to identify players for future scouting. We will focus on forwards for
# simplicity.

# %%
import pandas as pd
import numpy as np
import warnings
import os
import pathlib
import json

# %% [markdown]
# Import FBRef data from the top 5 leagues in the 20-21 season

# %%
data = pd.read_csv("FBRef_20-21_T5_Data.csv")
#Restrict to players who have played at least 500 minutes
data["Min"] = data["Min"].apply(lambda x: x.replace(",","")).astype(int)
#clean the data set
data1 = data.loc[data["Min"]> 500]
data1 = data1.reset_index(drop = True)
data1 = data1.fillna(0)
data1 = data1.loc[data1["Player"] != "Salvador Ferrer"]
data1 = data1.loc[data1["Player"] != "Jota"]

# %%
#extract the forwards
forwards = data1.loc[(data1['Pos'] == 'FW') | (data1['Pos'] == 'MF,FW') | (data1['Pos'] == 'FW,MF')]
forwards = forwards.reset_index()
#remove names, teams, etc.
AttFeat = forwards.iloc[:, 12:]

# %% [markdown]
# This data set is still fairly high dimensional and contains extraneous data like number of nutmegs for example.
# We will select features we think are relevant to identifying the play-style of forwards. In particular, we will
# restrict to per90 statistics, remove extraneous datapoints like the aformentioned nutmegs, and we will
# remove stats that indicate player quality like xG/90. This is because we only want to measure play-style, not player quality.
#
# Player quality is obviously incredibly important when identifying players for transfers, but we don't want players to be artificially identified because they both have similar production even though they play very different styles. For example, if you include the xG data in what follows the algorithm will spit out Danny Ings as one of the most similar players to Michail Antonio. Anyone who has watched these two players will recognize how different they are as strikers despite now playing for the same club, 3 years after this data was collected.

# %%
AFdf = AttFeat.iloc[:, [11, 15, 17, 19, 20, 23, 26, 29, 30, 31, 32, 33, 38, 39, 54, 55, 56, 57, 58, 59, 69, 70, 71, 76, 77, 79, 80, 81, 91, 92, 93, 105, 107, 108, 109, 110, 111, 112, 116]]
#Lets see the list of features
AFdf.columns
# Out:
# Index(['AvgShotDist', 'PassCmp/90', 'PassCmp%', 'PrgDistPass/90',
#        'ShortCmp/90', 'MedCmp/90', 'LongCmp/90', 'KeyPass/90',
#        'PassIntoThird/90', 'PassIntoBox/90', 'CrossIntoBox/90', 'ProgPass/90',
#        'PassUnderPress/90', 'Switches/90', 'PassLiveSCA/90', 'PassDeadSCA/90',
#        'DribSCA/90', 'ShSCA/90', 'FoulSCA/90', 'DefSCA/90', 'Def 3rdTkl/90',
#        'Mid 3rdTkl/90', 'Att 3rdTkl/90', 'PressAtt/90', 'SuccPress/90',
#        'Def 3rdPress/90', 'Mid 3rdPress/90', 'Att 3rdPress/90',
#        'Mid 3rdTchs/90', 'Att 3rdTchs/90', 'Att PenTchs/90', 'Carries/90',
#        'PrgDistCarry/90', 'ProgCarry/90', 'CarryIntoThird/90',
#        'CarryIntoBox/90', 'Miscontrol/90', 'Dispossessed/90',
#        'ProgPassReceived/90'],
#       dtype='object')

# %% [markdown]
# Let's now try the most naive way of identifying new players. We will pick a player whose play-style we like. For our purposes it will be Michail Antonio of West Ham United. Let's then just find the 5 players whose stats are closest to his.
#
# Note that we haven't scaled the data at all yet.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# %%
neigh = NearestNeighbors(n_neighbors = 5)
neigh.fit(AFdf)
# Out:
# NearestNeighbors()

# %%
#We first need to find the index of Michail Antonio
forwards.index[forwards['Player'] == 'Michail Antonio']
# Out:
# Index([8], dtype='int64')

# %%
#Now lets get Antonio's stats in a proper format
Antonio = AFdf.loc[8].to_numpy().reshape(1,-1)

# %%
#Find the 5 nearest neighbors to Antonio
neigh.kneighbors(Antonio)
# Out:
# C:\Users\Rob\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# (array([[ 0.        , 11.93583261, 13.46652888, 13.74782528, 14.12232984]]),
#  array([[  8,  14, 116, 174, 124]], dtype=int64))

# %%
#Now we have the indices of the players. Who are they?
forwards.loc[[8, 14, 116, 174, 124]]
# Out:
#      index             Player   Nation Pos      Squad                Comp  \
# 8      772    Michail Antonio  eng ENG  FW   West Ham  eng Premier League
# 14     778        Keita Baldé   sn SEN  FW  Sampdoria          it Serie A
# 116    881  Arnaud Kalimuendo   fr FRA  FW       Lens          fr Ligue 1
# 174    939      Karim Onisiwo   at AUT  FW   Mainz 05       de Bundesliga
# 124    889  Randal Kolo Muani   fr FRA  FW     Nantes          fr Ligue 1
#
#       Age    Born  MP  Starts  ...  PrgDistCarry/90  ProgCarry/90  \
# 8    30.0  1990.0  26      24  ...             84.4          4.89
# 14   25.0  1995.0  25      12  ...             82.4          4.59
# 116  18.0  2002.0  28      13  ...             89.4          5.19
# 174  28.0  1992.0  31      19  ...             82.0          4.10
# 124  21.0  1998.0  37      35  ...             78.4          4.07
#
#      CarryIntoThird/90  CarryIntoBox/90  Miscontrol/90  Dispossessed/90  \
# 8                 1.51             1.23           3.52             2.60
# 14                1.20             1.65           3.16             1.65
# 116               1.41             1.33           2.22             3.26
# 174               1.37             1.07           3.85             2.88
# 124               0.80             1.36           3.06             2.76
#
#      PassTarget/90  PassesReceived/90  PassRec%  ProgPassReceived/90
# 8             55.7               29.3      52.6                 8.77
# 14            55.6               30.3      54.5                10.20
# 116           50.1               28.4      56.8                 9.48
# 174           51.9               25.9      49.9                 8.34
# 124           45.5               23.2      51.0                 7.57
#
# [5 rows x 129 columns]

# %%
#Let's repeat with Messi
forwards.index[forwards['Player'] == 'Lionel Messi']
# Out:
# Index([360], dtype='int64')

# %%
Messi = AFdf.loc[360].to_numpy().reshape(1,-1)
neigh.kneighbors(Messi)
# Out:
# C:\Users\Rob\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# (array([[ 0.        , 26.91673086, 43.59618447, 62.23733365, 63.8992856 ]]),
#  array([[360, 556, 524, 302, 316]], dtype=int64))

# %%
forwards.loc[[556, 524, 302, 316]]
# Out:
#      index        Player  Nation    Pos        Squad        Comp   Age  \
# 556   1905        Neymar  br BRA  MF,FW    Paris S-G  fr Ligue 1  28.0
# 524   1873          Isco  es ESP  MF,FW  Real Madrid  es La Liga  28.0
# 302   1078    Papu Gómez  ar ARG  FW,MF     Atalanta  it Serie A  32.0
# 316   1092  Josip Iličić  si SVN  FW,MF     Atalanta  it Serie A  32.0
#
#        Born  MP  Starts  ...  PrgDistCarry/90  ProgCarry/90  \
# 556  1992.0  18      15  ...            245.3          13.8
# 524  1992.0  25       8  ...            219.9          11.0
# 302  1988.0  10       9  ...            218.6          11.6
# 316  1988.0  28      17  ...            198.5          12.1
#
#      CarryIntoThird/90  CarryIntoBox/90  Miscontrol/90  Dispossessed/90  \
# 556               4.59             1.46           4.01             4.33
# 524               3.37             0.69           2.18             1.49
# 302               4.86             0.41           1.08             1.35
# 316               4.00             2.12           2.88             3.76
#
#      PassTarget/90  PassesReceived/90  PassRec%  ProgPassReceived/90
# 556           82.2               70.5      85.8                11.70
# 524           78.5               70.5      89.8                 5.35
# 302           63.6               54.9      86.2                 5.41
# 316           79.1               64.2      81.1                12.10
#
# [4 rows x 129 columns]

# %% [markdown]
# We now recall that we didn't scale our data at the beginning. Let's now scale the data and redo the analysis.

# %%
scaler = StandardScaler()
AFdf_scaled = scaler.fit_transform(AFdf)

neigh_scaled = NearestNeighbors(n_neighbors = 5)
neigh_scaled.fit(AFdf_scaled)
# Out:
# NearestNeighbors()

# %%
neigh_scaled.kneighbors(AFdf_scaled[8].reshape(1,-1), return_distance = False)
# Out:
# array([[  8,  64, 241,  43, 166]], dtype=int64)

# %%
forwards.loc[[8, 64, 241, 43, 166]]
# Out:
#      index           Player   Nation Pos          Squad                Comp  \
# 8      772  Michail Antonio  eng ENG  FW       West Ham  eng Premier League
# 64     828       Edin Džeko   ba BIH  FW           Roma          it Serie A
# 241   1006    Callum Wilson  eng ENG  FW  Newcastle Utd  eng Premier League
# 43     807     Jhon Córdoba   co COL  FW     Hertha BSC       de Bundesliga
# 166    931   Ibrahima Niane   sn SEN  FW           Metz          fr Ligue 1
#
#       Age    Born  MP  Starts  ...  PrgDistCarry/90  ProgCarry/90  \
# 8    30.0  1990.0  26      24  ...             84.4          4.89
# 64   34.0  1986.0  27      20  ...             63.4          3.84
# 241  28.0  1992.0  26      23  ...             59.2          3.06
# 43   27.0  1993.0  21      17  ...             44.3          2.22
# 166  21.0  1999.0  10       9  ...             36.4          2.30
#
#      CarryIntoThird/90  CarryIntoBox/90  Miscontrol/90  Dispossessed/90  \
# 8                 1.51             1.23           3.52             2.60
# 64                1.23             0.99           3.00             2.07
# 241               1.16             1.03           2.93             2.28
# 43                0.94             0.88           2.87             1.99
# 166               0.54             0.41           4.59             2.03
#
#      PassTarget/90  PassesReceived/90  PassRec%  ProgPassReceived/90
# 8             55.7               29.3      52.6                 8.77
# 64            49.8               29.9      60.0                 9.90
# 241           47.3               19.8      41.9                 6.55
# 43            47.4               23.1      48.8                 7.49
# 166           47.7               27.0      56.7                10.10
#
# [5 rows x 129 columns]

# %%
neigh_scaled.kneighbors(AFdf_scaled[360].reshape(1,-1), return_distance = False)
# Out:
# array([[360, 556, 302, 316, 487]], dtype=int64)

# %%
forwards.loc[[360, 556, 302, 316, 487]]
# Out:
#      index             Player  Nation    Pos      Squad        Comp   Age  \
# 360   1136       Lionel Messi  ar ARG  FW,MF  Barcelona  es La Liga  33.0
# 556   1905             Neymar  br BRA  MF,FW  Paris S-G  fr Ligue 1  28.0
# 302   1078         Papu Gómez  ar ARG  FW,MF   Atalanta  it Serie A  32.0
# 316   1092       Josip Iličić  si SVN  FW,MF   Atalanta  it Serie A  32.0
# 487   1836  Philippe Coutinho  br BRA  MF,FW  Barcelona  es La Liga  28.0
#
#        Born  MP  Starts  ...  PrgDistCarry/90  ProgCarry/90  \
# 360  1987.0  35      33  ...            246.1          15.4
# 556  1992.0  18      15  ...            245.3          13.8
# 302  1988.0  10       9  ...            218.6          11.6
# 316  1988.0  28      17  ...            198.5          12.1
# 487  1992.0  12       8  ...            209.5          12.7
#
#      CarryIntoThird/90  CarryIntoBox/90  Miscontrol/90  Dispossessed/90  \
# 360               5.71             1.46           1.19             2.83
# 556               4.59             1.46           4.01             4.33
# 302               4.86             0.41           1.08             1.35
# 316               4.00             2.12           2.88             3.76
# 487               3.42             2.19           0.68             1.64
#
#      PassTarget/90  PassesReceived/90  PassRec%  ProgPassReceived/90
# 360           87.2               74.7      85.7                 8.27
# 556           82.2               70.5      85.8                11.70
# 302           63.6               54.9      86.2                 5.41
# 316           79.1               64.2      81.1                12.10
# 487           81.6               70.4      86.2                 8.36
#
# [5 rows x 129 columns]

# %% [markdown]
# After scaling, we see that there is almost no change in the players identified as being close to Messi. However, there is a very large change in the players similar to Antonio.
#
# If we look at our features, we see that there are a few features that are distances. These are progressive carry distance per 90 and progressive pass distance per 90. Without scaling the features, the algorithm will bias towards players who are more similar on these two numbers due to the large differences between different players. After scaling, there is less bias towards these two specific statistics.

# %% [markdown]
# Now lets use agglomerative clustering to cluster our forwards into groups. As a first attempt, we hypothesize that there are 5 large groups of forwards: wingers, false nines, target men, poachers, and second strikers

# %%
from sklearn.cluster import AgglomerativeClustering

scan = AgglomerativeClustering(n_clusters=5)

# %%
labels2 = scan.fit_predict(AFdf_scaled)

# %%
res2 = forwards.iloc[:, 1:6]
res2['label'] = labels2
res2[(res2['Player'] == 'Jack Grealish') | (res2['Player'] ==  'Lionel Messi') | (res2['Player'] == 'Roberto Firmino')
   | (res2['Player'] == 'Luis Suárez') | (res2['Player'] == 'Zlatan Ibrahimović')]
# Out:
#                  Player   Nation    Pos            Squad                Comp  \
# 70      Roberto Firmino   br BRA     FW        Liverpool  eng Premier League
# 96   Zlatan Ibrahimović   se SWE     FW            Milan          it Serie A
# 220         Luis Suárez   uy URU     FW  Atlético Madrid          es La Liga
# 306       Jack Grealish  eng ENG  FW,MF      Aston Villa  eng Premier League
# 360        Lionel Messi   ar ARG  FW,MF        Barcelona          es La Liga
#
#      label
# 70       3
# 96       3
# 220      1
# 306      2
# 360      2

# %% [markdown]
# Let's investigate each group to see what types of players are in each.

# %%
#look at zeros
res2[res2['label'] == 0]
# Out:
#                       Player   Nation    Pos            Squad  \
# 40           Samu Castillejo   es ESP     FW            Milan
# 123          Justin Kluivert   nl NED     FW       RB Leipzig
# 200      Alexis Saelemaekers   be BEL     FW            Milan
# 253             Aymen Barkok   ma MAR  FW,MF   Eint Frankfurt
# 265            Julian Brandt   de GER  FW,MF         Dortmund
# 287  Eric Junior Dina Ebimbe   fr FRA  FW,MF            Dijon
# 293      Fernando Forestieri   it ITA  FW,MF          Udinese
# 338              Érik Lamela   ar ARG  FW,MF        Tottenham
# 388              Yeremi Pino   es ESP  FW,MF       Villarreal
# 419            Romano Schmid   at AUT  FW,MF    Werder Bremen
# 443          Jeong Woo-yeong   kr KOR  FW,MF         Freiburg
# 455    Christoph Baumgartner   at AUT  MF,FW       Hoffenheim
# 460           Álex Berenguer   es ESP  MF,FW    Athletic Club
# 461             Daniel Bessa   it ITA  MF,FW    Hellas Verona
# 462     Leonardo Bittencourt   de GER  MF,FW    Werder Bremen
# 463             Ludovic Blas   fr FRA  MF,FW           Nantes
# 464         Antonin Bobichon   fr FRA  MF,FW           Angers
# 465        Jean-Paul Boëtius   nl NED  MF,FW         Mainz 05
# 468          Hicham Boudaoui   dz ALG  MF,FW             Nice
# 476         Daniel Caligiuri   it ITA  MF,FW         Augsburg
# 486        Lassana Coulibaly   ml MLI  MF,FW           Angers
# 488         Mikkel Damsgaard   dk DEN  MF,FW        Sampdoria
# 489      Romain Del Castillo   fr FRA  MF,FW           Rennes
# 491              Brahim Díaz   es ESP  MF,FW            Milan
# 492             Sofiane Diop   fr FRA  MF,FW           Monaco
# 497         Dominick Drexler   de GER  MF,FW             Köln
# 510         Yannick Gerhardt   de GER  MF,FW        Wolfsburg
# 514             Sergio Gómez   es ESP  MF,FW           Huesca
# 528       Geoffrey Kondogbia   cf CTA  MF,FW  Atlético Madrid
# 529              Rade Krunić   ba BIH  MF,FW            Milan
# 536              Enzo Le Fée   fr FRA  MF,FW          Lorient
# 538            Jesse Lingard  eng ENG  MF,FW         West Ham
# 541      Alexis Mac Allister   ar ARG  MF,FW         Brighton
# 545            Admir Mehmedi   ch SUI  MF,FW        Wolfsburg
# 547             Brais Méndez   es ESP  MF,FW       Celta Vigo
# 559                Dani Olmo   es ESP  MF,FW       RB Leipzig
# 562            Mario Pašalić   hr CRO  MF,FW         Atalanta
# 568              Ayoze Pérez   es ESP  MF,FW   Leicester City
# 574           Gastón Ramírez   uy URU  MF,FW        Sampdoria
# 575           Nathan Redmond  eng ENG  MF,FW      Southampton
# 578          Elvis Rexhbeçaj   de GER  MF,FW             Köln
# 592              Lars Stindl   de GER  MF,FW       M'Gladbach
# 594             Flavien Tait   fr FRA  MF,FW           Rennes
# 595           Lucas Torreira   uy URU  MF,FW  Atlético Madrid
# 598          Andros Townsend  eng ENG  MF,FW   Crystal Palace
# 602               Toni Villa   es ESP  MF,FW       Valladolid
# 604              Hannes Wolf   at AUT  MF,FW       M'Gladbach
# 609            Mehdi Zerkane   dz ALG  MF,FW         Bordeaux
#
#                    Comp  label
# 40           it Serie A      0
# 123       de Bundesliga      0
# 200          it Serie A      0
# 253       de Bundesliga      0
# 265       de Bundesliga      0
# 287          fr Ligue 1      0
# 293          it Serie A      0
# 338  eng Premier League      0
# 388          es La Liga      0
# 419       de Bundesliga      0
# 443       de Bundesliga      0
# 455       de Bundesliga      0
# 460          es La Liga      0
# 461          it Serie A      0
# 462       de Bundesliga      0
# 463          fr Ligue 1      0
# 464          fr Ligue 1      0
# 465       de Bundesliga      0
# 468          fr Ligue 1      0
# 476       de Bundesliga      0
# 486          fr Ligue 1      0
# 488          it Serie A      0
# 489          fr Ligue 1      0
# 491          it Serie A      0
# 492          fr Ligue 1      0
# 497       de Bundesliga      0
# 510       de Bundesliga      0
# 514          es La Liga      0
# 528          es La Liga      0
# 529          it Serie A      0
# 536          fr Ligue 1      0
# 538  eng Premier League      0
# 541  eng Premier League      0
# 545       de Bundesliga      0
# 547          es La Liga      0
# 559       de Bundesliga      0
# 562          it Serie A      0
# 568  eng Premier League      0
# 574          it Serie A      0
# 575  eng Premier League      0
# 578       de Bundesliga      0
# 592       de Bundesliga      0
# 594          fr Ligue 1      0
# 595          es La Liga      0
# 598  eng Premier League      0
# 602          es La Liga      0
# 604       de Bundesliga      0
# 609          fr Ligue 1      0

# %% [markdown]
# These look like a mix of wide forwards and attacking midfielders who look to score goals. If we repeat this with each group we see that we have a group of finishers, creative forwards, target men, and wingers. This classification is still not perfect, but it seems better than the attempt with the dimension reduced data.

# %%
wide_forwards = res2[res2['label'] == 0]
finishers = res2[res2['label'] == 1]
creators = res2[res2['label'] == 2]
targets = res2[res2['label'] == 3]
wingers = res2[res2['label'] == 4]

# %% [markdown]
# Let's now try to use these two methods to scout for a player. Let's imagine we are Aston Villa trying to replace Jack Grealish after his transfer to Man City. As a first attempt let's start with a list of players who are 'close' to Grealish.

# %%
neigh_scaled2 = NearestNeighbors(n_neighbors = 51)
neigh_scaled2.fit(AFdf_scaled)
# Out:
# NearestNeighbors(n_neighbors=51)

# %%
def fifty_nearest_players(player):
    index = forwards.index[forwards['Player'] == player]
    sims = neigh_scaled2.kneighbors(AFdf_scaled[index].reshape(1,-1), return_distance = False).tolist()
    return forwards.loc[sims[0]]

# %%
#get dataframe of 50 closest players
JG_close_df = fifty_nearest_players('Jack Grealish')
#remove Grealish
df = JG_close_df.iloc[1:, :]
#restrict to players younger than 25
df = df[df['Age'] < 25]
#npxG+xA at least 0.5/90
df = df[df['npxG+xA/90'] > 0.5]
df
# Out:
#      index              Player   Nation    Pos            Squad  \
# 413   1189        Jadon Sancho  eng ENG  FW,MF         Dortmund
# 275   1051      Kingsley Coman   fr FRA  FW,MF    Bayern Munich
# 363   1139   Aleksei Miranchuk   ru RUS  FW,MF         Atalanta
# 292   1068          Phil Foden  eng ENG  FW,MF  Manchester City
# 449   1798       Houssem Aouar   fr FRA  MF,FW             Lyon
# 197    962             Rodrygo   br BRA     FW      Real Madrid
# 252   1028         Leon Bailey   jm JAM  FW,MF       Leverkusen
# 375   1151  Christopher Nkunku   fr FRA  FW,MF       RB Leipzig
#
#                    Comp   Age    Born  MP  Starts  ...  PrgDistCarry/90  \
# 413       de Bundesliga  20.0  2000.0  26      24  ...            188.6
# 275       de Bundesliga  24.0  1996.0  29      23  ...            161.5
# 363          it Serie A  24.0  1995.0  25       4  ...            126.4
# 292  eng Premier League  20.0  2000.0  28      17  ...            124.3
# 449          fr Ligue 1  22.0  1998.0  30      23  ...            173.2
# 197          es La Liga  19.0  2001.0  22      10  ...            163.7
# 252       de Bundesliga  22.0  1997.0  30      25  ...            147.1
# 375       de Bundesliga  22.0  1997.0  28      19  ...            113.0
#
#      ProgCarry/90  CarryIntoThird/90  CarryIntoBox/90  Miscontrol/90  \
# 413         10.40               3.54             2.23           2.53
# 275         10.30               1.85             2.41           2.36
# 363          8.67               3.07             1.33           1.73
# 292          7.61               1.83             2.06           2.17
# 449          8.74               2.47             1.36           1.92
# 197          8.72               3.12             1.28           2.39
# 252          7.31               2.69             1.51           2.27
# 375          6.24               2.33             1.19           2.29
#
#      Dispossessed/90  PassTarget/90  PassesReceived/90  PassRec%  \
# 413             1.79           73.9               61.3      82.9
# 275             2.56           61.0               47.1      77.1
# 363             2.27           64.0               50.9      79.6
# 292             1.61           57.3               46.5      81.2
# 449             2.73           64.0               53.4      83.4
# 197             1.83           54.0               42.5      78.6
# 252             2.02           53.0               39.0      73.5
# 375             2.29           60.2               44.1      73.3
#
#      ProgPassReceived/90
# 413                 9.52
# 275                11.50
# 363                11.20
# 292                 8.83
# 449                 7.73
# 197                 7.06
# 252                 8.57
# 375                 9.57
#
# [8 rows x 129 columns]

# %% [markdown]
# Now we have a list of 8 players that are close in style and production to Grealish while also being under the age of 25. If we actually were passing these names to scouts, we would likely additionally remove Foden, Rodrygo, and Coman from the list.

# %% [markdown]
# Let's compare this to the list we would get from the clustering method.

# %%
#Grealish had label 2
forwards2 = forwards
forwards2['label'] = labels2
df2 = forwards2[forwards2['label'] == 2]
#players younger than 25
df2 = df2[df2['Age'] < 25]
#as productive as Grealish
df2 = df2[df2['npxG+xA/90'] > 0.5]
df2
# Out:
#      index             Player   Nation    Pos        Squad  \
# 306   1082      Jack Grealish  eng ENG  FW,MF  Aston Villa
# 413   1189       Jadon Sancho  eng ENG  FW,MF     Dortmund
# 449   1798      Houssem Aouar   fr FRA  MF,FW         Lyon
# 511   1860  Aleksandr Golovin   ru RUS  MF,FW       Monaco
#
#                    Comp   Age    Born  MP  Starts  ...  ProgCarry/90  \
# 306  eng Premier League  24.0  1995.0  26      24  ...         12.60
# 413       de Bundesliga  20.0  2000.0  26      24  ...         10.40
# 449          fr Ligue 1  22.0  1998.0  30      23  ...          8.74
# 511          fr Ligue 1  24.0  1996.0  21      12  ...          6.47
#
#      CarryIntoThird/90  CarryIntoBox/90  Miscontrol/90  Dispossessed/90  \
# 306               3.74             3.29           1.89             1.93
# 413               3.54             2.23           2.53             1.79
# 449               2.47             1.36           1.92             2.73
# 511               2.77             0.67           1.93             1.85
#
#      PassTarget/90  PassesReceived/90  PassRec%  ProgPassReceived/90  label
# 306           56.1               42.4      75.6                 7.49      2
# 413           73.9               61.3      82.9                 9.52      2
# 449           64.0               53.4      83.4                 7.73      2
# 511           51.1               39.5      77.3                 7.23      2
#
# [4 rows x 130 columns]

# %% [markdown]
# This leaves us with only 3 players to look at. We see that Sancho and Aouar are in both, while Golovin is unique to the clustering method.
# Both methods yield similar results, but if you rely on nearest neighbor it requires you to choose a player whose profile you want and it may become quite computationally expensive to find nearest neighbor sets for several different players, especially when the data is much higher dimensional. The clustering approach only requires you to have a rough idea of a profile in mind.
